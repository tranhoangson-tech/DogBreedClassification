# %%
import os

train_dir = "../dataset/train"

breeds = [
    d for d in os.listdir(train_dir)
    if os.path.isdir(os.path.join(train_dir, d))
]

print("Số giống chó:", len(breeds))
print("\n10 giống đầu tiên:")
print(breeds[:10])
# Out:
# Số giống chó: 28
#
# 10 giống đầu tiên:
# ['afghan_hound', 'african_hunting_dog', 'airedale', 'basenji', 'basset', 'beagle', 'bedlington_terrier', 'bernese_mountain_dog', 'black-and-tan_coonhound', 'blenheim_spaniel']

# %%
import os

train_dir = "../dataset/train"

breeds = sorted([
    d for d in os.listdir(train_dir)
    if os.path.isdir(os.path.join(train_dir, d))
])

for breed in breeds:
    print(breed)

print("\nTổng:", len(breeds))
# Out:
# afghan_hound
# african_hunting_dog
# airedale
# basenji
# basset
# beagle
# bedlington_terrier
# bernese_mountain_dog
# black-and-tan_coonhound
# blenheim_spaniel
# bloodhound
# bluetick
# border_collie
# border_terrier
# borzoi
# boston_bull
# bouvier_des_flandres
# brabancon_griffon
# bull_mastiff
# cairn
# cardigan
# chesapeake_bay_retriever
# chow
# clumber
# cocker_spaniel
# collie
# curly-coated_retriever
# dhole
#
# Tổng: 28

# %%
import os
import pandas as pd

train_dir = "../dataset/train"

rows = []

for breed in sorted(os.listdir(train_dir)):
    breed_path = os.path.join(train_dir, breed)

    if os.path.isdir(breed_path):
        count = len([
            f for f in os.listdir(breed_path)
            if f.lower().endswith((".jpg", ".jpeg", ".png"))
        ])

        rows.append([breed, count])

df = pd.DataFrame(rows, columns=["Breed", "Images"])

display(df)
# Out:
#                        Breed  Images
# 0               afghan_hound      92
# 1        african_hunting_dog      68
# 2                   airedale      85
# 3                    basenji      88
# 4                     basset      65
# 5                     beagle      84
# 6         bedlington_terrier      71
# 7       bernese_mountain_dog      91
# 8    black-and-tan_coonhound      61
# 9           blenheim_spaniel      81
# 10                bloodhound      68
# 11                  bluetick      68
# 12             border_collie      57
# 13            border_terrier      72
# 14                    borzoi      60
# 15               boston_bull      69
# 16      bouvier_des_flandres      68
# 17         brabancon_griffon      53
# 18              bull_mastiff      60
# 19                     cairn      84
# 20                  cardigan      60
# 21  chesapeake_bay_retriever      66
# 22                      chow      74
# 23                   clumber      64
# ...

# %%
import tensorflow as tf

print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.21.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# GPU: []

# %%
import tensorflow as tf

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    "dataset/train",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "dataset/val",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    "dataset/test",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 6
#       2
#       3 IMG_SIZE = (224, 224)
#       4 BATCH_SIZE = 32
#       5
# ----> 6 train_ds = tf.keras.utils.image_dataset_from_directory(
#       7     "dataset/train",
#       8     image_size=IMG_SIZE,
#       9     batch_size=BATCH_SIZE
#
# File d:\code_thui\DogBreedClassification\venv\Lib\site-packages\keras\src\utils\image_dataset_utils.py:265, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     263 if seed is None:
#     264     seed = np.random.randint(1e6)
# --> 265 image_paths, labels, class_names = dataset_utils.index_directory(
#     266     directory,
#     267     labels,
# ...

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# d:\code_thui\DogBreedClassification\notebooks
# ['dataset_check.ipynb']

# %%
import os

print(os.listdir(".."))
# Out:
# ['.venv', 'app', 'dataset', 'models', 'notebooks', 'reports', 'venv']

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "../dataset/train",
    image_size=(224,224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "../dataset/val",
    image_size=(224,224),
    batch_size=32
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    "../dataset/test",
    image_size=(224,224),
    batch_size=32
)
# Out:
# Found 1925 files belonging to 28 classes.
# Found 762 files belonging to 93 classes.
# Found 887 files belonging to 93 classes.

# %%
import os

print("Train:", len(os.listdir("../dataset/train")))
print("Val:", len(os.listdir("../dataset/val")))
print("Test:", len(os.listdir("../dataset/test")))
# Out:
# Train: 28
# Val: 93
# Test: 93

# %%
import os
import shutil

train_classes = set(os.listdir("../dataset/train"))

for breed in os.listdir("../dataset/val"):
    if breed not in train_classes:
        shutil.rmtree(os.path.join("../dataset/val", breed))

for breed in os.listdir("../dataset/test"):
    if breed not in train_classes:
        shutil.rmtree(os.path.join("../dataset/test", breed))

print("Done!")
# Out:
# Done!

# %%
print("Train:", len(os.listdir("../dataset/train")))
print("Val:", len(os.listdir("../dataset/val")))
print("Test:", len(os.listdir("../dataset/test")))
# Out:
# Train: 28
# Val: 28
# Test: 28

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "../dataset/train",
    image_size=(224,224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "../dataset/val",
    image_size=(224,224),
    batch_size=32
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    "../dataset/test",
    image_size=(224,224),
    batch_size=32
)
# Out:
# Found 1925 files belonging to 28 classes.
# Found 233 files belonging to 28 classes.
# Found 271 files belonging to 28 classes.

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255, input_shape=(224,224,3)),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(28, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# d:\code_thui\DogBreedClassification\venv\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ...

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)
# Out:
# Epoch 1/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 276ms/step - accuracy: 0.0462 - loss: 3.4649 - val_accuracy: 0.0472 - val_loss: 3.3196
# Epoch 2/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 15s 241ms/step - accuracy: 0.0525 - loss: 3.3201 - val_accuracy: 0.0601 - val_loss: 3.3022
# Epoch 3/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 15s 239ms/step - accuracy: 0.0686 - loss: 3.2619 - val_accuracy: 0.0687 - val_loss: 3.2467
# Epoch 4/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 16s 262ms/step - accuracy: 0.1101 - loss: 3.1230 - val_accuracy: 0.0730 - val_loss: 3.2041
# Epoch 5/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.1881 - loss: 2.8399 - val_accuracy: 0.0901 - val_loss: 3.2397
# Epoch 6/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.2810 - loss: 2.4335 - val_accuracy: 0.1116 - val_loss: 3.2918
# Epoch 7/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.4151 - loss: 2.0167 - val_accuracy: 0.1416 - val_loss: 3.5828
# Epoch 8/10
# ...

# %%
model.save("../models/cnn_basic.keras")

# %%
test_loss, test_acc = model.evaluate(test_ds)

print("Test Accuracy:", test_acc)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.1107 - loss: 4.4657
# Test Accuracy: 0.11070110648870468
